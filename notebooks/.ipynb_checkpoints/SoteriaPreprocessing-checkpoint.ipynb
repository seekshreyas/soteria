# %% [markdown]
# # Load and Preprocess the dataset

# %%
from __future__ import division
import pandas as pd
import numpy as np

# %%
# load data
df = pd.read_csv('../data/VCDB/data/csv/vcdb.csv')

# %%
for c in df.columns:
    print c, len(df[df[c].notnull() == False])
# Out:
# incident_id 0
# source_id 0
# reference 484
# security_incident 0
# summary 482
# related_incidents 3081
# notes
# 2925
# victim.country 0
# victim.employee_count 0
# victim.industry 0
# victim.locations_affected 2948
# victim.notes 3025
# victim.revenue.amount
# 2598
# victim.revenue.iso_currency_code 2598
# victim.secondary.amount 3002
# victim.secondary.victim_id
# 3002
# victim.state 931
# victim.victim_id 181
# actor.external.motive.Espionage 0
# actor.external.motive.Financial 0
# actor.external.motive.Fun 0
# actor.external.motive.Grudge 0
# actor.external.motive.Ideology 0
# actor.external.motive.NA 0
# actor.external.motive.Other 0
# actor.external.motive.Unknown 0
# actor.external.variety.Acquaintance 0
# actor.external.variety.Activist 0
# actor.external.variety.Competitor 0
# actor.external.variety.Customer 0
# actor.external.variety.Force.majeure 0
# actor.external.variety.Former.employee 0
# actor.external.variety.Nation.state 0
# ...
